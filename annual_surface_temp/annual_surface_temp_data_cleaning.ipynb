# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.float_format', '{:.3f}'.format)

# %% [markdown]
# **Dataset Overview**

# %%
# Read the CSV file
df = pd.read_csv("Annual_Surface_Temperature_Change.csv")
df
# Out:
#      ObjectId                       Country ISO2 ISO3  \
# 0           1  Afghanistan, Islamic Rep. of   AF  AFG
# 1           2                       Albania   AL  ALB
# 2           3                       Algeria   DZ  DZA
# 3           4                American Samoa   AS  ASM
# 4           5      Andorra, Principality of   AD  AND
# ..        ...                           ...  ...  ...
# 220       221                Western Sahara   EH  ESH
# 221       222                         World  NaN  WLD
# 222       223                Yemen, Rep. of   YE  YEM
# 223       224                        Zambia   ZM  ZMB
# 224       225                      Zimbabwe   ZW  ZWE
#
#                                              Indicator            Unit  \
# 0    Temperature change with respect to a baseline ...  Degree Celsius
# 1    Temperature change with respect to a baseline ...  Degree Celsius
# 2    Temperature change with respect to a baseline ...  Degree Celsius
# ...

# %%
# Check the column names
print(df.columns)
# Out:
# Index(['ObjectId', 'Country', 'ISO2', 'ISO3', 'Indicator', 'Unit', 'Source',
#        'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor', 'F1961', 'F1962',
#        'F1963', 'F1964', 'F1965', 'F1966', 'F1967', 'F1968', 'F1969', 'F1970',
#        'F1971', 'F1972', 'F1973', 'F1974', 'F1975', 'F1976', 'F1977', 'F1978',
#        'F1979', 'F1980', 'F1981', 'F1982', 'F1983', 'F1984', 'F1985', 'F1986',
#        'F1987', 'F1988', 'F1989', 'F1990', 'F1991', 'F1992', 'F1993', 'F1994',
#        'F1995', 'F1996', 'F1997', 'F1998', 'F1999', 'F2000', 'F2001', 'F2002',
#        'F2003', 'F2004', 'F2005', 'F2006', 'F2007', 'F2008', 'F2009', 'F2010',
#        'F2011', 'F2012', 'F2013', 'F2014', 'F2015', 'F2016', 'F2017', 'F2018',
#        'F2019', 'F2020', 'F2021', 'F2022'],
#       dtype='object')

# %%
# Select the relevant columns and create a new DataFrame
Sel_cols = ['Country', 'ISO2', 'ISO3', 'F2000', 'F2001', 'F2002',
       'F2003', 'F2004', 'F2005', 'F2006', 'F2007', 'F2008', 'F2009', 'F2010',
       'F2011', 'F2012', 'F2013', 'F2014', 'F2015', 'F2016', 'F2017', 'F2018',
       'F2019', 'F2020', 'F2021', 'F2022']
new_df = df[Sel_cols]
new_df
# Out:
#                           Country ISO2 ISO3  F2000  F2001  F2002  F2003  \
# 0    Afghanistan, Islamic Rep. of   AF  AFG  0.993  1.311  1.365  0.587
# 1                         Albania   AL  ALB  1.065  1.532  0.492  0.970
# 2                         Algeria   DZ  DZA  0.820  1.856  1.258  1.585
# 3                  American Samoa   AS  ASM  0.626  0.904  1.152  0.716
# 4        Andorra, Principality of   AD  AND  1.050  1.480  0.835  1.949
# ..                            ...  ...  ...    ...    ...    ...    ...
# 220                Western Sahara   EH  ESH  0.874  1.296  1.249  1.387
# 221                         World  NaN  WLD  0.728  0.834  1.021  0.893
# 222                Yemen, Rep. of   YE  YEM    NaN    NaN    NaN    NaN
# 223                        Zambia   ZM  ZMB -0.040  0.263  0.711  0.871
# 224                      Zimbabwe   ZW  ZWE -0.417  0.004  0.487  0.355
#
#      F2004  F2005  F2006  ...  F2013  F2014  F2015  F2016  F2017  F2018  \
# ...

# %%
# Summary statistics of the new DataFrame
new_df.describe()
# Out:
#         F2000   F2001   F2002   F2003   F2004   F2005   F2006   F2007   F2008  \
# count 209.000 208.000 212.000 214.000 213.000 212.000 215.000 217.000 212.000
# mean    0.670   0.850   0.925   0.844   0.778   0.853   0.877   1.023   0.808
# std     0.530   0.471   0.379   0.431   0.371   0.371   0.420   0.546   0.488
# min    -0.718  -0.186   0.009  -0.252  -0.622  -0.393  -0.505  -0.219  -0.139
# 25%     0.298   0.505   0.676   0.593   0.539   0.668   0.611   0.679   0.443
# 50%     0.537   0.728   0.840   0.844   0.729   0.839   0.835   0.921   0.692
# 75%     0.996   1.281   1.137   1.046   0.975   1.074   1.127   1.220   1.105
# max     2.066   1.992   2.255   2.328   2.150   2.201   2.343   2.729   2.607
#
#         F2009  ...   F2013   F2014   F2015   F2016   F2017   F2018   F2019  \
# count 212.000  ... 216.000 216.000 216.000 213.000 214.000 213.000 213.000
# mean    0.911  ...   0.931   1.115   1.270   1.440   1.281   1.302   1.443
# ...

# %%
# Check the NA for each column
new_df.isna().sum()
# Out:
# Country     0
# ISO2        2
# ISO3        0
# F2000      16
# F2001      17
# F2002      13
# F2003      11
# F2004      12
# F2005      13
# F2006      10
# F2007       8
# F2008      13
# F2009      13
# F2010      10
# F2011       8
# F2012      10
# F2013       9
# F2014       9
# F2015       9
# F2016      12
# F2017      11
# F2018      12
# F2019      12
# F2020      13
# F2021      12
# F2022      12
# dtype: int64

# %%
# Separate the columns into two groups for plotting
columns1 = new_df.columns[3:14]
columns2 = new_df.columns[14:26]

# %%
# First group of columns (2000 to 2010)
plt.Figure(figsize=(20, 10))
new_df[columns1].plot(kind='box', figsize=(15, 6), title='Annual Surface Temperature Change from 2000 to 2010')
plt.tight_layout()
plt.show()

# %%
# Second group of columns (2011 to 2022)
new_df[columns2].plot(kind='box', title='Annual Surface Temperature Change from 2011 to 2022', figsize=(15, 6))
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(20, 10))
axes = axes.flatten()

for i, col in enumerate(columns1):
    ax = axes[i]
    new_df[col].plot(kind='density', ax=ax, title=col)
    ax.axvline(new_df[col].mean(), color='red', linestyle='--', linewidth=1)
    ax.axvline(new_df[col].median(), color='green', linestyle='--', linewidth=1)
    ax.set_xlabel("Temp Change (°C)")
    ax.set_ylabel("Density")

# Remove any unused subplots
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(20, 10))
axes = axes.flatten()

for i, col in enumerate(columns2):
    ax = axes[i]
    new_df[col].plot(kind='density', ax=ax, title=col)
    ax.axvline(new_df[col].mean(), color='red', linestyle='--', linewidth=1)
    ax.axvline(new_df[col].median(), color='green', linestyle='--', linewidth=1)
    ax.set_xlabel("Temp Change (°C)")
    ax.set_ylabel("Density")

# Remove any unused subplots
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Data Cleaning**

# %%
# Impute NAs with the median of each column
df_imputed = new_df.fillna(round(new_df.median(numeric_only=True), 3))
df_imputed.isna().sum()
# Out:
# Country    0
# ISO2       2
# ISO3       0
# F2000      0
# F2001      0
# F2002      0
# F2003      0
# F2004      0
# F2005      0
# F2006      0
# F2007      0
# F2008      0
# F2009      0
# F2010      0
# F2011      0
# F2012      0
# F2013      0
# F2014      0
# F2015      0
# F2016      0
# F2017      0
# F2018      0
# F2019      0
# F2020      0
# F2021      0
# F2022      0
# dtype: int64

# %%
# New dataframe with imputed values
df_imputed
# Out:
#                           Country ISO2 ISO3  F2000  F2001  F2002  F2003  \
# 0    Afghanistan, Islamic Rep. of   AF  AFG  0.993  1.311  1.365  0.587
# 1                         Albania   AL  ALB  1.065  1.532  0.492  0.970
# 2                         Algeria   DZ  DZA  0.820  1.856  1.258  1.585
# 3                  American Samoa   AS  ASM  0.626  0.904  1.152  0.716
# 4        Andorra, Principality of   AD  AND  1.050  1.480  0.835  1.949
# ..                            ...  ...  ...    ...    ...    ...    ...
# 220                Western Sahara   EH  ESH  0.874  1.296  1.249  1.387
# 221                         World  NaN  WLD  0.728  0.834  1.021  0.893
# 222                Yemen, Rep. of   YE  YEM  0.537  0.728  0.840  0.844
# 223                        Zambia   ZM  ZMB -0.040  0.263  0.711  0.871
# 224                      Zimbabwe   ZW  ZWE -0.417  0.004  0.487  0.355
#
#      F2004  F2005  F2006  ...  F2013  F2014  F2015  F2016  F2017  F2018  \
# ...

# %%
# Check for any remaining NA values
na_rows = df_imputed[df_imputed.isna().any(axis=1)]
na_rows
# Out:
#      Country ISO2 ISO3  F2000  F2001  F2002  F2003  F2004  F2005  F2006  ...  \
# 138  Namibia  NaN  NAM -0.041  0.414  0.918  1.293  0.858  0.815 -0.079  ...
# 221    World  NaN  WLD  0.728  0.834  1.021  0.893  0.913  1.095  0.998  ...
#
#      F2013  F2014  F2015  F2016  F2017  F2018  F2019  F2020  F2021  F2022
# 138  0.759  0.439  1.215  1.473  0.818  1.110  1.821  0.601 -0.059  0.239
# 221  1.016  1.053  1.412  1.660  1.429  1.290  1.444  1.711  1.447  1.394
#
# [2 rows x 26 columns]

# %%
# World is not a country, so it can be removed from the DataFrame
df_imputed = df_imputed[df_imputed['Country'] != 'World']
df_imputed
# Out:
#                           Country ISO2 ISO3  F2000  F2001  F2002  F2003  \
# 0    Afghanistan, Islamic Rep. of   AF  AFG  0.993  1.311  1.365  0.587
# 1                         Albania   AL  ALB  1.065  1.532  0.492  0.970
# 2                         Algeria   DZ  DZA  0.820  1.856  1.258  1.585
# 3                  American Samoa   AS  ASM  0.626  0.904  1.152  0.716
# 4        Andorra, Principality of   AD  AND  1.050  1.480  0.835  1.949
# ..                            ...  ...  ...    ...    ...    ...    ...
# 219            West Bank and Gaza   PS  PSE  0.249  0.855  0.728  0.559
# 220                Western Sahara   EH  ESH  0.874  1.296  1.249  1.387
# 222                Yemen, Rep. of   YE  YEM  0.537  0.728  0.840  0.844
# 223                        Zambia   ZM  ZMB -0.040  0.263  0.711  0.871
# 224                      Zimbabwe   ZW  ZWE -0.417  0.004  0.487  0.355
#
#      F2004  F2005  F2006  ...  F2013  F2014  F2015  F2016  F2017  F2018  \
# ...

# %% [markdown]
# **Web Scraping**

# %%
# Import libraries for web scraping
from bs4 import BeautifulSoup
import requests

# %%
# Target URL
url = "https://www.countrycode.org/"

page = requests.get(url)

soup = BeautifulSoup(page.text, "html")

# %%
# Print the soup object to see the HTML content
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>         <html class="ie8" lang="en"> <![endif]--><!--[if IE 9]>         <html class="ie9" lang="en"> <![endif]--><!--[if gt IE 9]><!--><html lang="en"> <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>CountryCode.org: Country Codes, Phone Codes, Dialing Codes, Telephone Codes, ISO Country Codes</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="CountryCode.org: Country Codes, Phone Codes, Dialing Codes, Telephone Codes, ISO Country Codes" name="title"/>
# <meta content="Find more information about country codes, phone codes, and ISO country codes. We've got the phone codes you need for easy international calling!" name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="CountryCode.org" property="og:site_name"/>
# ...

# %%
# Find the table title
data_title = soup.find_all("th")[0:6]
data_title
# Out:
# [<th data-field="name" data-sortable="true">
#                              COUNTRY
#                          </th>,
#  <th data-field="code" data-formatter="country_code" data-sortable="true" data-sorter="code_sort">
#                              COUNTRY CODE
#                          </th>,
#  <th data-field="iso" data-sortable="true">
#                              ISO CODES
#                          </th>,
#  <th class="population-col" data-field="population" data-sortable="true" data-sorter="population_sort">
#                              POPULATION
#                          </th>,
#  <th data-field="area" data-sortable="true" data-sorter="population_sort">
#                              AREA KM<span class="superscript">2</span>
#  </th>,
#  <th data-field="gdp" data-sortable="true" data-sorter="gdp_sort_named">
#                              GDP $USD
#                          </th>]

# %%
# Table title extraction
table_title = [title.text.strip() for title in data_title]
print(table_title)
# Out:
# ['COUNTRY', 'COUNTRY CODE', 'ISO CODES', 'POPULATION', 'AREA KM2', 'GDP $USD']

# %%
# Data extraction from the table
column_data = soup.find_all("td")
column_data
# Out:
# [<td><a href="/afghanistan">Afghanistan</a></td>,
#  <td>93</td>,
#  <td>AF / AFG</td>,
#  <td>29,121,286</td>,
#  <td>647,500</td>,
#  <td>20.65 Billion</td>,
#  <td><a href="/albania">Albania</a></td>,
#  <td>355</td>,
#  <td>AL / ALB</td>,
#  <td>2,986,952</td>,
#  <td>28,748</td>,
#  <td>12.8 Billion</td>,
#  <td><a href="/algeria">Algeria</a></td>,
#  <td>213</td>,
#  <td>DZ / DZA</td>,
#  <td>34,586,184</td>,
#  <td>2,381,740</td>,
#  <td>215.7 Billion</td>,
#  <td><a href="/americansamoa">American Samoa</a></td>,
#  <td>1-684</td>,
#  <td>AS / ASM</td>,
#  <td>57,881</td>,
#  <td>199</td>,
#  <td>462.2 Million</td>,
#  <td><a href="/andorra">Andorra</a></td>,
#  <td>376</td>,
#  <td>AD / AND</td>,
#  <td>84,000</td>,
#  <td>468</td>,
#  <td>4.8 Billion</td>,
#  <td><a href="/angola">Angola</a></td>,
#  <td>244</td>,
#  <td>AO / AGO</td>,
#  <td>13,068,161</td>,
#  <td>1,246,700</td>,
#  <td>124 Billion</td>,
#  <td><a href="/anguilla">Anguilla</a></td>,
#  <td>1-264</td>,
# ...

# %%
# Data extracted into a list
column_data = [data.text.strip() for data in column_data]
column_data
# Out:
# ['Afghanistan',
#  '93',
#  'AF / AFG',
#  '29,121,286',
#  '647,500',
#  '20.65 Billion',
#  'Albania',
#  '355',
#  'AL / ALB',
#  '2,986,952',
#  '28,748',
#  '12.8 Billion',
#  'Algeria',
#  '213',
#  'DZ / DZA',
#  '34,586,184',
#  '2,381,740',
#  '215.7 Billion',
#  'American Samoa',
#  '1-684',
#  'AS / ASM',
#  '57,881',
#  '199',
#  '462.2 Million',
#  'Andorra',
#  '376',
#  'AD / AND',
#  '84,000',
#  '468',
#  '4.8 Billion',
#  'Angola',
#  '244',
#  'AO / AGO',
#  '13,068,161',
#  '1,246,700',
#  '124 Billion',
#  'Anguilla',
#  '1-264',
#  'AI / AIA',
#  '13,254',
#  '102',
#  '175.4 Million',
#  'Antarctica',
#  '672',
#  'AQ / ATA',
#  '0',
#  '14,000,000',
#  '',
#  'Antigua and Barbuda',
#  '1-268',
#  'AG / ATG',
#  '86,754',
#  '443',
#  '1.22 Billion',
#  'Argentina',
#  '54',
#  'AR / ARG',
#  '41,343,201',
#  '2,766,890',
#  '484.6 Billion',
#  'Armenia',
#  '374',
#  'AM / ARM',
#  '2,968,000',
#  '29,800',
#  '10.44 Billion',
#  'Aruba',
#  '297',
# ...

# %%
# Make sure the data is in chunk format
chunk_size = 6

rows = [column_data[i:i+chunk_size] for i in range(0, len(column_data), chunk_size)]

# %%
# Store the data in a DataFrame
df_country = pd.DataFrame(rows, columns=table_title)
df_country
# Out:
#             COUNTRY COUNTRY CODE ISO CODES         POPULATION   AREA KM2  \
# 0       Afghanistan           93  AF / AFG         29,121,286    647,500
# 1           Albania          355  AL / ALB          2,986,952     28,748
# 2           Algeria          213  DZ / DZA         34,586,184  2,381,740
# 3    American Samoa        1-684  AS / ASM             57,881        199
# 4           Andorra          376  AD / AND             84,000        468
# ..              ...          ...       ...                ...        ...
# 355      Uzbekistan          998  UZ / UZB            Vanuatu        678
# 356         Vatican          379  VA / VAT          Venezuela         58
# 357         Vietnam           84  VN / VNM  Wallis and Futuna        681
# 358  Western Sahara          212  EH / ESH              Yemen        967
# 359          Zambia          260  ZM / ZMB           Zimbabwe        263
#
#           GDP $USD
# 0    20.65 Billion
# 1     12.8 Billion
# 2    215.7 Billion
# ...

# %%
# Drop unnecessary columns
df_country = df_country.drop(columns=['COUNTRY CODE', 'POPULATION', 'AREA KM2', 'GDP $USD'])

# %%
# Display the remaining columns
df_country
# Out:
#             COUNTRY ISO CODES
# 0       Afghanistan  AF / AFG
# 1           Albania  AL / ALB
# 2           Algeria  DZ / DZA
# 3    American Samoa  AS / ASM
# 4           Andorra  AD / AND
# ..              ...       ...
# 355      Uzbekistan  UZ / UZB
# 356         Vatican  VA / VAT
# 357         Vietnam  VN / VNM
# 358  Western Sahara  EH / ESH
# 359          Zambia  ZM / ZMB
#
# [360 rows x 2 columns]

# %%
# Split the 'ISO CODES' column into 'ISO1' and 'ISO2'
df_country[['ISO1', 'ISO2']] = df_country['ISO CODES'].str.split('/', expand=True)

# %%
# Final  DataFrame with relevant columns
df_country
# Out:
#             COUNTRY ISO CODES ISO1  ISO2
# 0       Afghanistan  AF / AFG  AF    AFG
# 1           Albania  AL / ALB  AL    ALB
# 2           Algeria  DZ / DZA  DZ    DZA
# 3    American Samoa  AS / ASM  AS    ASM
# 4           Andorra  AD / AND  AD    AND
# ..              ...       ...  ...   ...
# 355      Uzbekistan  UZ / UZB  UZ    UZB
# 356         Vatican  VA / VAT  VA    VAT
# 357         Vietnam  VN / VNM  VN    VNM
# 358  Western Sahara  EH / ESH  EH    ESH
# 359          Zambia  ZM / ZMB  ZM    ZMB
#
# [360 rows x 4 columns]

# %% [markdown]
# **Merge Dataset**

# %%
# Read the country codes CSV file
df_countryCode = pd.read_csv("country_codes.csv")

# %%
# Remove leading and trailing spaces from ISO codes
df_imputed['ISO3'] = df_imputed['ISO3'].str.strip()
df_countryCode['ISO2'] = df_countryCode['ISO2'].str.strip()
# Out:
# C:\Users\Yap Hui Qing\AppData\Local\Temp\ipykernel_12712\2385950905.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_imputed['ISO3'] = df_imputed['ISO3'].str.strip()

# %%
# Merge 2 DataFrames on ISO codes
complete_df = pd.merge(df_imputed, df_countryCode, left_on='ISO3', right_on='ISO2', how='left')
complete_df
# Out:
#                           Country ISO2_x ISO3  F2000  F2001  F2002  F2003  \
# 0    Afghanistan, Islamic Rep. of     AF  AFG  0.993  1.311  1.365  0.587
# 1    Afghanistan, Islamic Rep. of     AF  AFG  0.993  1.311  1.365  0.587
# 2                         Albania     AL  ALB  1.065  1.532  0.492  0.970
# 3                         Algeria     DZ  DZA  0.820  1.856  1.258  1.585
# 4                         Algeria     DZ  DZA  0.820  1.856  1.258  1.585
# ..                            ...    ...  ...    ...    ...    ...    ...
# 333                Western Sahara     EH  ESH  0.874  1.296  1.249  1.387
# 334                Yemen, Rep. of     YE  YEM  0.537  0.728  0.840  0.844
# 335                        Zambia     ZM  ZMB -0.040  0.263  0.711  0.871
# 336                        Zambia     ZM  ZMB -0.040  0.263  0.711  0.871
# 337                      Zimbabwe     ZW  ZWE -0.417  0.004  0.487  0.355
#
#      F2004  F2005  F2006  ...  F2017  F2018  F2019  F2020  F2021  F2022  \
# ...

# %%
# Drop duplicate
complete_df = complete_df.drop_duplicates()
complete_df
# Out:
#                           Country ISO2_x ISO3  F2000  F2001  F2002  F2003  \
# 0    Afghanistan, Islamic Rep. of     AF  AFG  0.993  1.311  1.365  0.587
# 2                         Albania     AL  ALB  1.065  1.532  0.492  0.970
# 3                         Algeria     DZ  DZA  0.820  1.856  1.258  1.585
# 5                  American Samoa     AS  ASM  0.626  0.904  1.152  0.716
# 6        Andorra, Principality of     AD  AND  1.050  1.480  0.835  1.949
# ..                            ...    ...  ...    ...    ...    ...    ...
# 331            West Bank and Gaza     PS  PSE  0.249  0.855  0.728  0.559
# 332                Western Sahara     EH  ESH  0.874  1.296  1.249  1.387
# 334                Yemen, Rep. of     YE  YEM  0.537  0.728  0.840  0.844
# 335                        Zambia     ZM  ZMB -0.040  0.263  0.711  0.871
# 337                      Zimbabwe     ZW  ZWE -0.417  0.004  0.487  0.355
#
#      F2004  F2005  F2006  ...  F2017  F2018  F2019  F2020  F2021  F2022  \
# ...

# %%
# Check for any remaining NA values in the merged DataFrame
na_rows = complete_df[complete_df.isna().any(axis=1)]
na_rows
# Out:
#             Country ISO2_x ISO3  F2000  F2001  F2002  F2003  F2004  F2005  \
# 122      Guadeloupe     GP  GLP  0.279  0.557  0.695  0.816  0.507  0.827
# 188      Martinique     MQ  MTQ  0.262  0.506  0.681  0.802  0.515  0.834
# 208         Namibia    NaN  NAM -0.041  0.414  0.918  1.293  0.858  0.815
# 223  Norfolk Island     NF  NFK -0.051  0.250  0.166  0.045  0.294  0.326
#
#      F2006  ...  F2017  F2018  F2019  F2020  F2021  F2022  COUNTRY  ISO CODES  \
# 122  0.698  ...  0.907  0.620  0.803  1.160  0.826  0.773      NaN        NaN
# 188  0.736  ...  0.800  0.540  0.752  1.092  0.716  0.684      NaN        NaN
# 208 -0.079  ...  0.818  1.110  1.821  0.601 -0.059  0.239  Namibia   NA / NAM
# 223  0.208  ...  0.717  0.700  0.667  0.705  0.613  1.225      NaN        NaN
#
#      ISO1  ISO2_y
# 122   NaN     NaN
# 188   NaN     NaN
# 208   NA      NAM
# 223   NaN     NaN
#
# [4 rows x 30 columns]

# %%
# Fill missing ISO2 values with ISO1 values
complete_df['ISO2_x'] = complete_df['ISO2_x'].fillna(complete_df['ISO1'])
# Out:
# C:\Users\Yap Hui Qing\AppData\Local\Temp\ipykernel_12712\2614738697.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complete_df['ISO2_x'] = complete_df['ISO2_x'].fillna(complete_df['ISO1'])

# %%
# Standardize the Country column
complete_df['Country'] = complete_df['COUNTRY'].combine_first(complete_df['Country'])
# Out:
# C:\Users\Yap Hui Qing\AppData\Local\Temp\ipykernel_12712\2928819120.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complete_df['Country'] = complete_df['COUNTRY'].combine_first(complete_df['Country'])

# %%
# Drop unnecessary columns
complete_df = complete_df.drop(columns=['COUNTRY', 'ISO CODES', 'ISO1', 'ISO2_y'])

# %%
# Rename columns
complete_df = complete_df.rename(columns={
    'ISO2_x': 'ISO1',
    'ISO3': 'ISO2'
})
complete_df
# Out:
#             Country ISO1 ISO2  F2000  F2001  F2002  F2003  F2004  F2005  \
# 0       Afghanistan   AF  AFG  0.993  1.311  1.365  0.587  1.373  0.401
# 2           Albania   AL  ALB  1.065  1.532  0.492  0.970  0.444  0.189
# 3           Algeria   DZ  DZA  0.820  1.856  1.258  1.585  0.988  1.264
# 5    American Samoa   AS  ASM  0.626  0.904  1.152  0.716  0.191  0.801
# 6           Andorra   AD  AND  1.050  1.480  0.835  1.949  0.936  0.851
# ..              ...  ...  ...    ...    ...    ...    ...    ...    ...
# 331       Palestine   PS  PSE  0.249  0.855  0.728  0.559  0.554  0.196
# 332  Western Sahara   EH  ESH  0.874  1.296  1.249  1.387  1.550  1.210
# 334           Yemen   YE  YEM  0.537  0.728  0.840  0.844  0.729  0.839
# 335          Zambia   ZM  ZMB -0.040  0.263  0.711  0.871  0.606  0.948
# 337        Zimbabwe   ZW  ZWE -0.417  0.004  0.487  0.355 -0.004  0.945
#
#      F2006  ...  F2013  F2014  F2015  F2016  F2017  F2018  F2019  F2020  \
# ...

# %%
'''
complete_df.to_csv('complete_annual_surface_temp.csv', 
          index=False, 
          encoding='utf-8-sig')
          '''
